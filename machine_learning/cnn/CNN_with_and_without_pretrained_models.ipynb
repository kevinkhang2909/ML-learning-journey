# %%
try:
  # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x  #gpu
except Exception:
    pass

import tensorflow as tf

print(tf.__version__)
tf.executing_eagerly()
# Out:
# 2.0.0
# True

# %%
import pathlib
import random

def load_image(image_dir, image_size):
    image = tf.io.read_file(image_dir)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.cast(image, tf.float32)
    image = (image/255)
    image = tf.image.resize(image, (image_size, image_size))
    return image

data_dir = tf.keras.utils.get_file(
    'flower_photos', 'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz', untar=True)
data_dir = pathlib.Path(data_dir)

image_dirs = list(data_dir.glob('*/*'))
image_dirs = [str(path) for path in image_dirs]
random.shuffle(image_dirs)
IMG_SIZE = 160

# TODO:
# 1. list files and assign the right label corresponding to each image
#    based on the filepath of each image

# %%
! ls $data_dir
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
label_names = {
    'daisy': 0,
    'dandelion': 1,
    'roses': 2,
    'sunflowers': 3,
    'tulips': 4,
}

X = [load_image(path, IMG_SIZE) for path in image_dirs]
y = [label_names[pathlib.Path(path).parent.name] for path in image_dirs]

X = tf.convert_to_tensor(X)

y = tf.convert_to_tensor(y)

# ===================

X_train, X_test, y_train, y_test = train_test_split(
    X.numpy(), y.numpy(), test_size=0.2)

X_train = tf.convert_to_tensor(X_train)
X_test = tf.convert_to_tensor(X_test)
y_train = tf.convert_to_tensor(y_train)
y_test = tf.convert_to_tensor(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c77dc17ec07c> in <module>
#      16 # ===================
#      17
# ---> 18 X_train, X_test, y_train, y_test = train_test_split(
#      19     X.numpy(), y.numpy(), test_size=0.2)
#      20
#
# NameError: name 'train_test_split' is not defined

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),

    # TODO: fill suitable activations
    tf.keras.layers.Dense(units=100, activation='relu'),
    tf.keras.layers.Dense(units=5, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy',
            optimizer=tf.keras.optimizers.Adam(),
            metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10)
model.evaluate(X_test, y_test)
# Out:
# Train on 2936 samples
# Epoch 1/10
# 2936/2936 [==============================] - 43s 15ms/sample - loss: 1.6841 - accuracy: 0.2238
# Epoch 2/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6056 - accuracy: 0.2384
# Epoch 3/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6034 - accuracy: 0.2384
# Epoch 4/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6026 - accuracy: 0.2384
# Epoch 5/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6022 - accuracy: 0.2384
# Epoch 6/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6023 - accuracy: 0.2384
# Epoch 7/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6021 - accuracy: 0.2384
# Epoch 8/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6021 - accuracy: 0.2384
# Epoch 9/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6021 - accuracy: 0.2384
# Epoch 10/10
# 2936/2936 [==============================] - 41s 14ms/sample - loss: 1.6021 - accuracy: 0.2384
# 734/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [1.594139753635313, 0.26975477]

# %%
model.evaluate(X_test, y_test)
# Out:
# 1835/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [1.4688722756643062, 0.5400545]

# %%
# 3. implement simple CNN with:
#    - 1 Convolution layer 2D, 32 filters, filter size 3, activation: relu
#    - 1 MaxPooling layer 2D
# 4. evaluate model with test set
